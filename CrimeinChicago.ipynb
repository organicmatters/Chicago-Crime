# %% [markdown]
# # Crime in Chicago

# %% [markdown]
# The objective of this project is to predict whether a person who committed a particular crime was arrested.

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine  
import pickle
import feather
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# This is the local data path
#data_path = '/Users/kevin/Downloads/Crimes_-_2001_to_paresent.csv'

# %%
weather_data_path = '/Users/kevin/Downloads/1598904.csv'

# %%
iucr_codes = '/Users/kevin/Downloads/Chicago_Police_Department_-_Illinois_Uniform_Crime_Reporting__IUCR__Codes.csv'

# %% [markdown]
# /Users/kevin/Downloads/Chicago_Police_Department_-_Illinois_Uniform_Crime_Reporting__IUCR__Codes.csv

# %% [markdown]
# CREATE TABLE IF NOT EXISTS ChicagoCrime (
#         ID integer,
#         CaseNumber varchar(20),
#         Date varchar(50),
#         Block varchar(50),
#         IUCR varchar(10),
#         PrimaryType varchar(50),
#         Description varchar(100),
#         LocationDescription varchar(150),
#         Arrest varchar(10),
#         Domestic varchar(10),
#         Beat integer,
#         District real,
#         Ward real,
#         CommunityArea real,
#         FBICode varchar(10),
#         XCoordinate varchar(20),
#         YCoordinate varchar(20),
#         Year integer,
#         UpdatedOn varchar(50),
#         Latitude varchar(15),
#         Longitude varchar(15),
#         Location varchar(50)
#     );

# %% [markdown]
# ## Pull Data From Server

# %%
cnx = create_engine('postgresql://ubuntu:@54.91.118.64:5432/chicago')

# %%
df = pd.read_sql_query('''SELECT * FROM chicagocrime''', cnx)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in connect(self)
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     346
# --> 347         return _ConnectionRecord(self)
#     348
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     473         if connect:
# --> 474             self.__connect(first_connect_check=True)
#     475         self.finalize_callback = deque()
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#
# /anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#
# OperationalError: could not connect to server: Operation timed out
# 	Is the server running on host "54.91.118.64" and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-14-793a5fa3084e> in <module>
# ----> 1 df = pd.read_sql_query('''SELECT * FROM chicagocrime''', cnx)
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     312     return pandas_sql.read_query(
#     313         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 314         parse_dates=parse_dates, chunksize=chunksize)
#     315
#     316
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1061         args = _convert_params(sql, params)
#    1062
# -> 1063         result = self.execute(*args)
#    1064         columns = result.keys()
#    1065
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#     952     def execute(self, *args, **kwargs):
#     953         """Simple passthrough to SQLAlchemy connectable"""
# --> 954         return self.connectable.execute(*args, **kwargs)
#     955
#     956     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2072         """
#    2073
# -> 2074         connection = self.contextual_connect(close_with_result=True)
#    2075         return connection.execute(statement, *multiparams, **params)
#    2076
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in contextual_connect(self, close_with_result, **kwargs)
#    2121         return self._connection_cls(
#    2122             self,
# -> 2123             self._wrap_pool_connect(self.pool.connect, None),
#    2124             close_with_result=close_with_result,
#    2125             **kwargs)
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in connect(self)
#     398         """
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#     402         try:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     786     def _checkout(cls, pool, threadconns=None, fairy=None):
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#     790             fairy._pool = pool
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     527     @classmethod
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#     531             dbapi_connection = rec.get_connection()
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1191             except:
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#    1195             return self._do_get()
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     247         if value.__traceback__ is not tb:
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#     251 else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1188         if self._inc_overflow():
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#    1192                 with util.safe_reraise():
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     345         """Called by subclasses to create a new ConnectionRecord."""
#     346
# --> 347         return _ConnectionRecord(self)
#     348
#     349     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     472         self.__pool = pool
#     473         if connect:
# --> 474             self.__connect(first_connect_check=True)
#     475         self.finalize_callback = deque()
#     476
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     669         try:
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#     673             self.connection = connection
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     410
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#     414     def create_connect_args(self, url):
#
# /anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     128
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#     132         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Operation timed out
# 	Is the server running on host "54.91.118.64" and accepting
# 	TCP/IP connections on port 5432?
#  (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
df.head()
# Out:
#          id casenumber                    date                   block  iucr  \
# 0  10000092   HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 1  10000094   HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 2  10000095   HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 3  10000096   HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 4  10000097   HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#      primarytype              description locationdescription arrest domestic  \
# 0        BATTERY      AGGRAVATED: HANDGUN              STREET  false    false
# 1  OTHER OFFENSE         PAROLE VIOLATION              STREET   true    false
# 2        BATTERY  DOMESTIC BATTERY SIMPLE           APARTMENT  false     true
# 3        BATTERY                   SIMPLE           APARTMENT  false    false
# 4        ROBBERY           ARMED: HANDGUN            SIDEWALK  false    false
#
#                ...                ward  communityarea  fbicode  xcoordinate  \
# 0              ...                28.0           25.0      04B      1144606
# 1              ...                15.0           67.0       26      1166468
# 2              ...                 4.0           39.0      08B      1185075
# 3              ...                 3.0           40.0      08B      1178033
# 4              ...                28.0           25.0       03      1144920
#
#   ycoordinate  year               updatedon      latitude      longitude  \
# 0     1903566  2015  02/10/2018 03:50:01 PM  41.891398861  -87.744384567
# 1     1860715  2015  02/10/2018 03:50:01 PM  41.773371528  -87.665319468
# 2     1875622  2015  02/10/2018 03:50:01 PM   41.81386068  -87.596642837
# 3     1870804  2015  02/10/2018 03:50:01 PM  41.800802415  -87.622619343
# 4     1898709  2015  02/10/2018 03:50:01 PM  41.878064761  -87.743354013
#
#                         location
# 0  (41.891398861, -87.744384567)
# 1  (41.773371528, -87.665319468)
# 2   (41.81386068, -87.596642837)
# 3  (41.800802415, -87.622619343)
# 4  (41.878064761, -87.743354013)
#
# [5 rows x 22 columns]

# %%
df['datetime'] = pd.to_datetime(df['date'], infer_datetime_format=True)

# %%
mask = df['arrest']  == 'true'
print('Percent of Crimes ending in Arrest: ' + len(df[mask])/len(df)

# %%
#df.to_feather('chicago_crime.feather')

# %%
df = feather.read_dataframe('chicago_crime')

# %%
df.head()
# Out:
#          id casenumber                    date                   block  iucr  \
# 0  10000092   HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 1  10000094   HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 2  10000095   HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 3  10000096   HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 4  10000097   HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#      primarytype              description locationdescription arrest domestic  \
# 0        BATTERY      AGGRAVATED: HANDGUN              STREET  false    false
# 1  OTHER OFFENSE         PAROLE VIOLATION              STREET   true    false
# 2        BATTERY  DOMESTIC BATTERY SIMPLE           APARTMENT  false     true
# 3        BATTERY                   SIMPLE           APARTMENT  false    false
# 4        ROBBERY           ARMED: HANDGUN            SIDEWALK  false    false
#
#           ...          communityarea  fbicode  xcoordinate  ycoordinate  year  \
# 0         ...                   25.0      04B      1144606      1903566  2015
# 1         ...                   67.0       26      1166468      1860715  2015
# 2         ...                   39.0      08B      1185075      1875622  2015
# 3         ...                   40.0      08B      1178033      1870804  2015
# 4         ...                   25.0       03      1144920      1898709  2015
#
#                 updatedon      latitude      longitude  \
# 0  02/10/2018 03:50:01 PM  41.891398861  -87.744384567
# 1  02/10/2018 03:50:01 PM  41.773371528  -87.665319468
# 2  02/10/2018 03:50:01 PM   41.81386068  -87.596642837
# 3  02/10/2018 03:50:01 PM  41.800802415  -87.622619343
# 4  02/10/2018 03:50:01 PM  41.878064761  -87.743354013
#
#                         location            datetime
# 0  (41.891398861, -87.744384567) 2015-03-18 19:44:00
# 1  (41.773371528, -87.665319468) 2015-03-18 23:00:00
# 2   (41.81386068, -87.596642837) 2015-03-18 22:45:00
# 3  (41.800802415, -87.622619343) 2015-03-18 22:30:00
# 4  (41.878064761, -87.743354013) 2015-03-18 21:00:00
#
# [5 rows x 23 columns]

# %% [markdown]
# You have the IUCR codes so pull in the description for those codes in your downloads

# %% [markdown]
# Can check Chicago Economy for more data

# %% [markdown]
# ## Read in Weather Data

# %%
df_weather = pd.read_csv(weather_data_path)

# %% [markdown]
# WT03 - Thunder
# WT04 - Ice pellets, sleet, snow pellets, or small hail"
# PRCP - Precipitation
# WT05 - Hail (may include small hail)
# WV03 - Thunder
# WT06 - Glaze or rime
# WT07 - Dust, volcanic ash, blowing dust, blowing sand, or blowing obstruction
# WT08 - Smoke or haze
# SNWD - Snow depth
# WT09 - Blowing or drifting snow
# WDF2 - Direction of fastest 2-minute wind
# WDF5 - Direction of fastest 5-second wind
# PGTM - Peak gust time
# WT11 - High or damaging winds
# TMAX - Maximum temperature
# WT13 - Mist
# WSF2 - Fastest 2-minute wind speed
# FMTM - Time of fastest mile or fastest 1-minute wind
# WSF5 - Fastest 5-second wind speed
# SNOW - Snowfall
# WT14 - Drizzle
# WT15 - Freezing drizzle
# WT16 - Rain (may include freezing rain, drizzle, and freezing drizzle)"
# WT17 - Freezing rain
# WT18 - Snow, snow pellets, snow grains, or ice crystals
# WT19 - Unknown source of precipitation
# AWND - Average wind speed
# WT21 - Ground fog
# WT22 - Ice fog or freezing fog
# WV20 - Rain or snow shower
# WT01 - Fog, ice fog, or freezing fog (may include heavy fog)
# WESD - Water equivalent of snow on the ground
# WT02 - Heavy fog or heaving freezing fog (not always distinguished from fog)
# TAVG - Average Temperature.
# TMIN - Minimum temperature
# TSUN - Total sunshine for the period

# %%
df_weather.columns = map(str.lower, df_weather.columns)

# %%
df_weather['datetime'] = pd.to_datetime(df_weather['date'], infer_datetime_format=True)

# %% [markdown]
# ## Merge Weather Data and Crime Data

# %%
df_weather = df_weather.sort_values('datetime')

# %%
df = df.sort_values('datetime')

# %%
cw_df = pd.merge_asof(df, df_weather, on = 'datetime', direction = 'backward', tolerance = pd.Timedelta('1 day'))

# %%
#iucr_df = pd.read_csv(iucr_codes)

# %%
#df = cw_df.set_index('iucr').join(iucr_df.set_index('IUCR'))

# %%
df = cw_df.reset_index()

# %%
df.to_feather('chicago_crime_and_weather.feather')

# %% [markdown]
# ## View the Entire Dataset

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %%
display_all(df)
# Out:
#                               primarytype  \
# 1              OFFENSE INVOLVING CHILDREN
# 2              OFFENSE INVOLVING CHILDREN
# 3                           OTHER OFFENSE
# 4              OFFENSE INVOLVING CHILDREN
# 5                                   THEFT
# 6                      DECEPTIVE PRACTICE
# 7                                   THEFT
# 8                                 ASSAULT
# 9                                   THEFT
# 10             OFFENSE INVOLVING CHILDREN
# 11                                  THEFT
# 12                                  THEFT
# 13                     DECEPTIVE PRACTICE
# 14             OFFENSE INVOLVING CHILDREN
# 15                        CRIMINAL DAMAGE
# 16                        CRIMINAL DAMAGE
# 17                    CRIM SEXUAL ASSAULT
# 19                                  THEFT
# 21                                  THEFT
# 22                                  THEFT
# 30                    CRIM SEXUAL ASSAULT
# 32                                  THEFT
# 33                                  THEFT
# 34                                  THEFT
# 35                                  THEFT
# 37                                  THEFT
# 38                        CRIMINAL DAMAGE
# 39             OFFENSE INVOLVING CHILDREN
# 40                        CRIMINAL DAMAGE
# 41                            SEX OFFENSE
# 42                                  THEFT
# 43                                  THEFT
# 44                    CRIM SEXUAL ASSAULT
# 45                        CRIMINAL DAMAGE
# 46                                  THEFT
# 47                                  THEFT
# 48                                  THEFT
# 49             OFFENSE INVOLVING CHILDREN
# 50                                  THEFT
# 51                          OTHER OFFENSE
# 52                                  THEFT
# 54                                  THEFT
# 55                     DECEPTIVE PRACTICE
# 56                                  THEFT
# 57                                  THEFT
# 58             OFFENSE INVOLVING CHILDREN
# 59                                  THEFT
# 60                                  THEFT
# 61                                  THEFT
# 62                     DECEPTIVE PRACTICE
# 63                                  THEFT
# 67                     DECEPTIVE PRACTICE
# 68                        CRIMINAL DAMAGE
# 69                        CRIMINAL DAMAGE
# 70                          OTHER OFFENSE
# 71                          OTHER OFFENSE
# 72                    CRIM SEXUAL ASSAULT
# 74                                  THEFT
# 75             OFFENSE INVOLVING CHILDREN
# 76                            SEX OFFENSE
# 77                    CRIM SEXUAL ASSAULT
# 78                                ASSAULT
# 79                                  THEFT
# 81             OFFENSE INVOLVING CHILDREN
# 82                     DECEPTIVE PRACTICE
# 83                                  THEFT
# 84             OFFENSE INVOLVING CHILDREN
# 85                                  THEFT
# 86                    CRIM SEXUAL ASSAULT
# 87             OFFENSE INVOLVING CHILDREN
# 88             OFFENSE INVOLVING CHILDREN
# 89                                  THEFT
# 90                                  THEFT
# 91                     DECEPTIVE PRACTICE
# 92                        CRIMINAL DAMAGE
# 93                                  THEFT
# 94                                BATTERY
# 95                                  THEFT
# 96                                  THEFT
# 97             OFFENSE INVOLVING CHILDREN
# 98                          OTHER OFFENSE
# 99                    CRIM SEXUAL ASSAULT
# 108                                 THEFT
# 111                                 THEFT
# 112                                 THEFT
# 114                                 THEFT
# 128                                 THEFT
# 129            OFFENSE INVOLVING CHILDREN
# 131                           SEX OFFENSE
# 132                                 THEFT
# 133                                 THEFT
# 134                                 THEFT
# 135            OFFENSE INVOLVING CHILDREN
# 136                       CRIMINAL DAMAGE
# 137                         OTHER OFFENSE
# 138                                 THEFT
# 139                                 THEFT
# 140                                 THEFT
# 141                                 THEFT
# 142            OFFENSE INVOLVING CHILDREN
# 143                           SEX OFFENSE
# 144            OFFENSE INVOLVING CHILDREN
# 145                                 THEFT
# 146                                 THEFT
# 147                         OTHER OFFENSE
# 148                                 THEFT
# 149                    DECEPTIVE PRACTICE
# 150                                 THEFT
# 151                    DECEPTIVE PRACTICE
# 152                                 THEFT
# 153                                 THEFT
# 154                                 THEFT
# 155                                 THEFT
# 156            OFFENSE INVOLVING CHILDREN
# 157                                 THEFT
# 158                   CRIM SEXUAL ASSAULT
# 159            OFFENSE INVOLVING CHILDREN
# 160                                 THEFT
# 161                                 THEFT
# 162                   CRIM SEXUAL ASSAULT
# 163                    DECEPTIVE PRACTICE
# 164                   CRIM SEXUAL ASSAULT
# 165                                 THEFT
# 166                                 THEFT
# 167                                 THEFT
# 168                                 THEFT
# 169                                 THEFT
# 170                                 THEFT
# 172                    DECEPTIVE PRACTICE
# 174            OFFENSE INVOLVING CHILDREN
# 175                                 THEFT
# 176                                 THEFT
# 177            OFFENSE INVOLVING CHILDREN
# 178            OFFENSE INVOLVING CHILDREN
# 179                                 THEFT
# 180                           SEX OFFENSE
# 181                                 THEFT
# 182                                 THEFT
# 183            OFFENSE INVOLVING CHILDREN
# 184                         OTHER OFFENSE
# 185                       CRIMINAL DAMAGE
# 186                       CRIMINAL DAMAGE
# 187                       CRIMINAL DAMAGE
# 188                    DECEPTIVE PRACTICE
# 190                                 THEFT
# 191                           SEX OFFENSE
# 192            OFFENSE INVOLVING CHILDREN
# 194                                 THEFT
# 195                                 THEFT
# 196                                 THEFT
# 197                                 THEFT
# 198                                 THEFT
# 199            OFFENSE INVOLVING CHILDREN
# 200                   CRIM SEXUAL ASSAULT
# 201                                 THEFT
# 202                                 THEFT
# 203                       CRIMINAL DAMAGE
# 204                                 THEFT
# 205                                 THEFT
# 206                                 THEFT
# 207                                 THEFT
# 208                                 THEFT
# 209                   CRIM SEXUAL ASSAULT
# 211                         OTHER OFFENSE
# 212                    DECEPTIVE PRACTICE
# 213                    DECEPTIVE PRACTICE
# 214                   CRIM SEXUAL ASSAULT
# 215                                 THEFT
# 216                    DECEPTIVE PRACTICE
# 217            OFFENSE INVOLVING CHILDREN
# 219                       CRIMINAL DAMAGE
# 220            OFFENSE INVOLVING CHILDREN
# 221                                 THEFT
# 222            OFFENSE INVOLVING CHILDREN
# 223                               BATTERY
# 224                                 THEFT
# 226                   MOTOR VEHICLE THEFT
# 227            OFFENSE INVOLVING CHILDREN
# 228                         OTHER OFFENSE
# 229                    DECEPTIVE PRACTICE
# 230            OFFENSE INVOLVING CHILDREN
# 231                                 THEFT
# 232                           SEX OFFENSE
# 233            OFFENSE INVOLVING CHILDREN
# 234            OFFENSE INVOLVING CHILDREN
# 235            OFFENSE INVOLVING CHILDREN
# 237                                 THEFT
# 238                                 THEFT
# 239                                 THEFT
# 240            OFFENSE INVOLVING CHILDREN
# 241                   MOTOR VEHICLE THEFT
# 242                   CRIM SEXUAL ASSAULT
# 243                                 THEFT
# 245                                 THEFT
# 246            OFFENSE INVOLVING CHILDREN
# 247                    DECEPTIVE PRACTICE
# 248            OFFENSE INVOLVING CHILDREN
# 249                       CRIMINAL DAMAGE
# 250            OFFENSE INVOLVING CHILDREN
# 251            OFFENSE INVOLVING CHILDREN
# 252                    DECEPTIVE PRACTICE
# 253                                 THEFT
# 254                           SEX OFFENSE
# 255            OFFENSE INVOLVING CHILDREN
# 256                                 THEFT
# 258            OFFENSE INVOLVING CHILDREN
# 259                                 THEFT
# 260                                 THEFT
# 261            OFFENSE INVOLVING CHILDREN
# 262            OFFENSE INVOLVING CHILDREN
# 263                    DECEPTIVE PRACTICE
# 264                       CRIMINAL DAMAGE
# 265                                 THEFT
# 266            OFFENSE INVOLVING CHILDREN
# 267                    DECEPTIVE PRACTICE
# 268                                 THEFT
# 269                   MOTOR VEHICLE THEFT
# 271                    DECEPTIVE PRACTICE
# 272            OFFENSE INVOLVING CHILDREN
# 273            OFFENSE INVOLVING CHILDREN
# 274                    DECEPTIVE PRACTICE
# 275                                 THEFT
# 276                                 THEFT
# 277                                 THEFT
# 278            OFFENSE INVOLVING CHILDREN
# 279                         OTHER OFFENSE
# 280                   CRIM SEXUAL ASSAULT
# 281                   CRIM SEXUAL ASSAULT
# 282                                 THEFT
# 283            OFFENSE INVOLVING CHILDREN
# 284                           SEX OFFENSE
# 285                    DECEPTIVE PRACTICE
# 286                           SEX OFFENSE
# 287                                 THEFT
# 288                       CRIMINAL DAMAGE
# 289                                 THEFT
# 290                           SEX OFFENSE
# 291                         OTHER OFFENSE
# 292                           SEX OFFENSE
# 293                   CRIM SEXUAL ASSAULT
# 294                                 THEFT
# 295                                 THEFT
# 296                                 THEFT
# 297                    DECEPTIVE PRACTICE
# 298            OFFENSE INVOLVING CHILDREN
# 300                                 THEFT
# 301                           SEX OFFENSE
# 302                           SEX OFFENSE
# 303                                 THEFT
# 304            OFFENSE INVOLVING CHILDREN
# 305            OFFENSE INVOLVING CHILDREN
# 306                   MOTOR VEHICLE THEFT
# 307                                 THEFT
# 308                              BURGLARY
# 309                       CRIMINAL DAMAGE
# 310                                 THEFT
# 312                                 THEFT
# 313            OFFENSE INVOLVING CHILDREN
# 314                       CRIMINAL DAMAGE
# 315                                 THEFT
# 316                                 THEFT
# 317                                 THEFT
# 318                           SEX OFFENSE
# 319            OFFENSE INVOLVING CHILDREN
# 320                           SEX OFFENSE
# 321            OFFENSE INVOLVING CHILDREN
# 322                   CRIM SEXUAL ASSAULT
# 323            OFFENSE INVOLVING CHILDREN
# 324                    DECEPTIVE PRACTICE
# 325                                 THEFT
# 326            OFFENSE INVOLVING CHILDREN
# 327                    DECEPTIVE PRACTICE
# 328                                 THEFT
# 329            OFFENSE INVOLVING CHILDREN
# 330                                 THEFT
# 331                     WEAPONS VIOLATION
# 332                     WEAPONS VIOLATION
# 333                               BATTERY
# 334                       CRIMINAL DAMAGE
# 335                   MOTOR VEHICLE THEFT
# 336                     WEAPONS VIOLATION
# 337                     CRIMINAL TRESPASS
# 338            OFFENSE INVOLVING CHILDREN
# 339                     WEAPONS VIOLATION
# 340                       CRIMINAL DAMAGE
# 341                   MOTOR VEHICLE THEFT
# 342                               BATTERY
# 343                       CRIMINAL DAMAGE
# 344                   MOTOR VEHICLE THEFT
# 345                       CRIMINAL DAMAGE
# 346                       CRIMINAL DAMAGE
# 347                       CRIMINAL DAMAGE
# 348                       CRIMINAL DAMAGE
# 349                               BATTERY
# 350                     CRIMINAL TRESPASS
# 351                       CRIMINAL DAMAGE
# 352                     WEAPONS VIOLATION
# 353                     WEAPONS VIOLATION
# 354                       CRIMINAL DAMAGE
# 355                               BATTERY
# 356                     WEAPONS VIOLATION
# 357                     WEAPONS VIOLATION
# 358                         OTHER OFFENSE
# 359                               BATTERY
# 360                               ROBBERY
# 361                     WEAPONS VIOLATION
# 362                               BATTERY
# 363                       CRIMINAL DAMAGE
# 364                             NARCOTICS
# 365                       CRIMINAL DAMAGE
# 366                       CRIMINAL DAMAGE
# 367                       CRIMINAL DAMAGE
# 368                                 THEFT
# 369                     WEAPONS VIOLATION
# 370                               BATTERY
# 371                       CRIMINAL DAMAGE
# 372                       CRIMINAL DAMAGE
# 373                   MOTOR VEHICLE THEFT
# 374                         OTHER OFFENSE
# 375                       CRIMINAL DAMAGE
# 376                       CRIMINAL DAMAGE
# 377                               BATTERY
# 378                       CRIMINAL DAMAGE
# 379                               BATTERY
# 380                   MOTOR VEHICLE THEFT
# 381                       CRIMINAL DAMAGE
# 382                       CRIMINAL DAMAGE
# 383                         OTHER OFFENSE
# 384                               BATTERY
# 385                       CRIMINAL DAMAGE
# 386                       CRIMINAL DAMAGE
# 387                               ROBBERY
# 388                               BATTERY
# 389                       CRIMINAL DAMAGE
# 390                               BATTERY
# 391                       CRIMINAL DAMAGE
# 392                     CRIMINAL TRESPASS
# 393                     WEAPONS VIOLATION
# 394                       CRIMINAL DAMAGE
# 395                       CRIMINAL DAMAGE
# 396                             NARCOTICS
# 397                       CRIMINAL DAMAGE
# 398                             NARCOTICS
# 399                               ASSAULT
# 400                               BATTERY
# 401                       CRIMINAL DAMAGE
# 402                     WEAPONS VIOLATION
# 403                     CRIMINAL TRESPASS
# 404                               BATTERY
# 405                       CRIMINAL DAMAGE
# 406                    DECEPTIVE PRACTICE
# 407                               BATTERY
# 408                               BATTERY
# 409                     WEAPONS VIOLATION
# 410                     WEAPONS VIOLATION
# 411                               ASSAULT
# 412                    DECEPTIVE PRACTICE
# 413                       CRIMINAL DAMAGE
# 414                                 THEFT
# 415                       CRIMINAL DAMAGE
# 416                         OTHER OFFENSE
# 417                    DECEPTIVE PRACTICE
# 418                               BATTERY
# 419                                 THEFT
# 420                               ASSAULT
# 421                                 THEFT
# 422                       CRIMINAL DAMAGE
# 423                               BATTERY
# 424                               BATTERY
# 425                           SEX OFFENSE
# 426                       CRIMINAL DAMAGE
# 427                   CRIM SEXUAL ASSAULT
# 428                       CRIMINAL DAMAGE
# 429                       CRIMINAL DAMAGE
# 430                       CRIMINAL DAMAGE
# 431                         OTHER OFFENSE
# 432                       CRIMINAL DAMAGE
# 433                               BATTERY
# 434                     WEAPONS VIOLATION
# 435                                 THEFT
# 436                               BATTERY
# 437                       CRIMINAL DAMAGE
# 438                       CRIMINAL DAMAGE
# 439            OFFENSE INVOLVING CHILDREN
# 440                               BATTERY
# 441                                 THEFT
# 442                       CRIMINAL DAMAGE
# 443            OFFENSE INVOLVING CHILDREN
# 444                       CRIMINAL DAMAGE
# 445                   CRIM SEXUAL ASSAULT
# 446                  LIQUOR LAW VIOLATION
# 447                               ASSAULT
# 448                               BATTERY
# 449                         OTHER OFFENSE
# 450                    DECEPTIVE PRACTICE
# 451                       CRIMINAL DAMAGE
# 452                       CRIMINAL DAMAGE
# 453                               ASSAULT
# 454                               ROBBERY
# 455                               BATTERY
# 456                              BURGLARY
# 457                PUBLIC PEACE VIOLATION
# 458                             NARCOTICS
# 459                               BATTERY
# 460                       CRIMINAL DAMAGE
# 461                  LIQUOR LAW VIOLATION
# 462                               BATTERY
# 463                     WEAPONS VIOLATION
# 464                               ROBBERY
# 465                               BATTERY
# 466                   MOTOR VEHICLE THEFT
# 467                               BATTERY
# 468                               BATTERY
# 469                                 THEFT
# 470                                 THEFT
# 471                               BATTERY
# 472                       CRIMINAL DAMAGE
# 473                               ROBBERY
# 474                               BATTERY
# 475                   CRIM SEXUAL ASSAULT
# 476                               BATTERY
# 477                               BATTERY
# 478                       CRIMINAL DAMAGE
# 479                               ASSAULT
# 480                               BATTERY
# 481                                 THEFT
# 482                       CRIMINAL DAMAGE
# 483                     WEAPONS VIOLATION
# 484                     WEAPONS VIOLATION
# 485                         OTHER OFFENSE
# 486                       CRIMINAL DAMAGE
# 487                               BATTERY
# 488                               BATTERY
# 489                               BATTERY
# 490                       CRIMINAL DAMAGE
# 491                       CRIMINAL DAMAGE
# 492                               BATTERY
# 493                     WEAPONS VIOLATION
# 494                     WEAPONS VIOLATION
# 495                       CRIMINAL DAMAGE
# 496                     WEAPONS VIOLATION
# 497                       CRIMINAL DAMAGE
# 498                                 THEFT
# 500                       CRIMINAL DAMAGE
# 501                   MOTOR VEHICLE THEFT
# 502                               BATTERY
# 503                               BATTERY
# 504                               BATTERY
# 505                       CRIMINAL DAMAGE
# 506                       CRIMINAL DAMAGE
# 507                       CRIMINAL DAMAGE
# 508                               BATTERY
# 509                                 THEFT
# 510                                 THEFT
# 511                       CRIMINAL DAMAGE
# 512                         OTHER OFFENSE
# 513                         OTHER OFFENSE
# 514                               BATTERY
# 515                       CRIMINAL DAMAGE
# 516                       CRIMINAL DAMAGE
# 517                         OTHER OFFENSE
# 518                               BATTERY
# 519                               BATTERY
# 520                                 THEFT
# 521                               BATTERY
# 522                               BATTERY
# 523                   MOTOR VEHICLE THEFT
# 524                              BURGLARY
# 525                               ASSAULT
# 526                       CRIMINAL DAMAGE
# 527                         OTHER OFFENSE
# 528                       CRIMINAL DAMAGE
# 529                     CRIMINAL TRESPASS
# 530                               ASSAULT
# 531                       CRIMINAL DAMAGE
# 532                       CRIMINAL DAMAGE
# 533                       CRIMINAL DAMAGE
# 534                     CRIMINAL TRESPASS
# 535                       CRIMINAL DAMAGE
# 536                               BATTERY
# 537                               BATTERY
# 538                               ASSAULT
# 539                               BATTERY
# 540                               BATTERY
# 541                       CRIMINAL DAMAGE
# 542                       CRIMINAL DAMAGE
# 543                               BATTERY
# 544                  LIQUOR LAW VIOLATION
# 545                     WEAPONS VIOLATION
# 546                               BATTERY
# 547                     WEAPONS VIOLATION
# 548                       CRIMINAL DAMAGE
# 549                   MOTOR VEHICLE THEFT
# 550                           SEX OFFENSE
# 551                               BATTERY
# 552                             NARCOTICS
# 553                       CRIMINAL DAMAGE
# 554                               BATTERY
# 555                               BATTERY
# 556                               BATTERY
# ...                                   ...
# 6797007                           ROBBERY
# 6797008                   CRIMINAL DAMAGE
# 6797009                           ASSAULT
# 6797010                           BATTERY
# 6797011                          BURGLARY
# 6797012                   CRIMINAL DAMAGE
# 6797013                         NARCOTICS
# 6797014                         NARCOTICS
# 6797015                         NARCOTICS
# 6797016                         NARCOTICS
# 6797017                         NARCOTICS
# 6797018                           ROBBERY
# 6797019                         NARCOTICS
# 6797020                         NARCOTICS
# 6797021                         NARCOTICS
# 6797022                         NARCOTICS
# 6797023                         NARCOTICS
# 6797024                         NARCOTICS
# 6797025                         NARCOTICS
# 6797026                         NARCOTICS
# 6797027                         NARCOTICS
# 6797028                         NARCOTICS
# 6797029                         NARCOTICS
# 6797030                 CRIMINAL TRESPASS
# 6797031                DECEPTIVE PRACTICE
# 6797032                         NARCOTICS
# 6797033                           BATTERY
# 6797034        OFFENSE INVOLVING CHILDREN
# 6797035                           ASSAULT
# 6797036                           ROBBERY
# 6797037                           BATTERY
# 6797038                         NARCOTICS
# 6797039                   CRIMINAL DAMAGE
# 6797040                             THEFT
# 6797041                           ASSAULT
# 6797042                             THEFT
# 6797043                           BATTERY
# 6797044                         NARCOTICS
# 6797045                         NARCOTICS
# 6797046                   CRIMINAL DAMAGE
# 6797047                 CRIMINAL TRESPASS
# 6797048                          BURGLARY
# 6797049                             THEFT
# 6797050                             THEFT
# 6797051                         NARCOTICS
# 6797052               MOTOR VEHICLE THEFT
# 6797053                 CRIMINAL TRESPASS
# 6797054                   CRIMINAL DAMAGE
# 6797055                 CRIMINAL TRESPASS
# 6797056                          BURGLARY
# 6797057                           ASSAULT
# 6797058                           ASSAULT
# 6797059                           BATTERY
# 6797060                             THEFT
# 6797061                           BATTERY
# 6797062                DECEPTIVE PRACTICE
# 6797063                DECEPTIVE PRACTICE
# 6797064                             THEFT
# 6797065                     OTHER OFFENSE
# 6797066                           BATTERY
# 6797067                           ASSAULT
# 6797068                             THEFT
# 6797069                 CRIMINAL TRESPASS
# 6797070                DECEPTIVE PRACTICE
# 6797071                           BATTERY
# 6797072                             THEFT
# 6797073                         NARCOTICS
# 6797074                         NARCOTICS
# 6797077                         NARCOTICS
# 6797078                           BATTERY
# 6797079                           BATTERY
# 6797080                           BATTERY
# 6797081                           BATTERY
# 6797082                           ASSAULT
# 6797083                           ASSAULT
# 6797084                           ASSAULT
# 6797085                             THEFT
# 6797086                             THEFT
# 6797087                         NARCOTICS
# 6797088                         NARCOTICS
# 6797089                           BATTERY
# 6797090                DECEPTIVE PRACTICE
# 6797091                             THEFT
# 6797092                         NARCOTICS
# 6797093                           BATTERY
# 6797094                DECEPTIVE PRACTICE
# 6797095                   CRIMINAL DAMAGE
# 6797096                           BATTERY
# 6797097                             THEFT
# 6797098                           ROBBERY
# 6797099                             THEFT
# 6797100                           ASSAULT
# 6797101                             THEFT
# 6797102                             THEFT
# 6797103                           BATTERY
# 6797104                 WEAPONS VIOLATION
# 6797105                         NARCOTICS
# 6797107                           ASSAULT
# 6797108                             THEFT
# 6797109                 CRIMINAL TRESPASS
# 6797110                           BATTERY
# 6797111                           ROBBERY
# 6797112                         NARCOTICS
# 6797113                         NARCOTICS
# 6797114                           BATTERY
# 6797115                           BATTERY
# 6797116                             THEFT
# 6797117                     OTHER OFFENSE
# 6797118                             THEFT
# 6797119                     OTHER OFFENSE
# 6797120                             THEFT
# 6797121                         NARCOTICS
# 6797122                             THEFT
# 6797123                           BATTERY
# 6797124        OFFENSE INVOLVING CHILDREN
# 6797126                             THEFT
# 6797127                         NARCOTICS
# 6797128                           ASSAULT
# 6797129                             THEFT
# 6797130                             THEFT
# 6797131                 WEAPONS VIOLATION
# 6797132                         NARCOTICS
# 6797133                         NARCOTICS
# 6797134                     OTHER OFFENSE
# 6797137                           BATTERY
# 6797138                             THEFT
# 6797139                     OTHER OFFENSE
# 6797140                         NARCOTICS
# 6797141                         NARCOTICS
# 6797142                             THEFT
# 6797143                     OTHER OFFENSE
# 6797144                         NARCOTICS
# 6797145                     OTHER OFFENSE
# 6797146                           BATTERY
# 6797147                             THEFT
# 6797148                         NARCOTICS
# 6797149                   CRIMINAL DAMAGE
# 6797150                         NARCOTICS
# 6797151                           BATTERY
# 6797152                     OTHER OFFENSE
# 6797153                DECEPTIVE PRACTICE
# 6797154                     OTHER OFFENSE
# 6797155                             THEFT
# 6797156                             THEFT
# 6797157                     OTHER OFFENSE
# 6797158                             THEFT
# 6797159                           BATTERY
# 6797160                     OTHER OFFENSE
# 6797161                           BATTERY
# 6797162                         NARCOTICS
# 6797163                         NARCOTICS
# 6797164                         NARCOTICS
# 6797165                         NARCOTICS
# 6797166               CRIM SEXUAL ASSAULT
# 6797167                           BATTERY
# 6797168                             THEFT
# 6797169                      INTIMIDATION
# 6797170                           BATTERY
# 6797171                   CRIMINAL DAMAGE
# 6797172                DECEPTIVE PRACTICE
# 6797173                           BATTERY
# 6797174                           ROBBERY
# 6797175                           BATTERY
# 6797176                             THEFT
# 6797177                     OTHER OFFENSE
# 6797178                             THEFT
# 6797179                DECEPTIVE PRACTICE
# 6797180                             THEFT
# 6797182                 CRIMINAL TRESPASS
# 6797183                     OTHER OFFENSE
# 6797184                   CRIMINAL DAMAGE
# 6797185                     OTHER OFFENSE
# 6797186                           BATTERY
# 6797187                     OTHER OFFENSE
# 6797188                           BATTERY
# 6797189                     OTHER OFFENSE
# 6797190                           ASSAULT
# 6797191                             THEFT
# 6797192                             THEFT
# 6797193                             THEFT
# 6797194                           BATTERY
# 6797195                           ROBBERY
# 6797196                         NARCOTICS
# 6797198                   CRIMINAL DAMAGE
# 6797199                   CRIMINAL DAMAGE
# 6797200                         NARCOTICS
# 6797201                           BATTERY
# 6797202                           BATTERY
# 6797203                             THEFT
# 6797205                             THEFT
# 6797206                DECEPTIVE PRACTICE
# 6797208                             THEFT
# 6797209                             THEFT
# 6797210                     OTHER OFFENSE
# 6797211               CRIM SEXUAL ASSAULT
# 6797212                             THEFT
# 6797213                             THEFT
# 6797214                         NARCOTICS
# 6797215                             THEFT
# 6797216                         NARCOTICS
# 6797217                             THEFT
# 6797218                           ASSAULT
# 6797219                DECEPTIVE PRACTICE
# 6797220                 CRIMINAL TRESPASS
# 6797221                   CRIMINAL DAMAGE
# 6797222                     OTHER OFFENSE
# 6797223                          BURGLARY
# 6797224            PUBLIC PEACE VIOLATION
# 6797225                DECEPTIVE PRACTICE
# 6797226                         NARCOTICS
# 6797227                           ASSAULT
# 6797228                             THEFT
# 6797229                     OTHER OFFENSE
# 6797230                             THEFT
# 6797231                             THEFT
# 6797232                          BURGLARY
# 6797233                             THEFT
# 6797234                             THEFT
# 6797235                DECEPTIVE PRACTICE
# 6797236                           BATTERY
# 6797237                             THEFT
# 6797238                DECEPTIVE PRACTICE
# 6797239                           ASSAULT
# 6797240                             THEFT
# 6797241                           ASSAULT
# 6797242                             THEFT
# 6797243                           ASSAULT
# 6797244                             THEFT
# 6797245                 CRIMINAL TRESPASS
# 6797246                           ASSAULT
# 6797247                           ASSAULT
# 6797248                             THEFT
# 6797249                           ASSAULT
# 6797250                   CRIMINAL DAMAGE
# 6797251                           ROBBERY
# 6797252                             THEFT
# 6797253                           ROBBERY
# 6797254                           BATTERY
# 6797255                          BURGLARY
# 6797256                             THEFT
# 6797258                           BATTERY
# 6797259                           BATTERY
# 6797260                             THEFT
# 6797261                          BURGLARY
# 6797262                       SEX OFFENSE
# 6797263                             THEFT
# 6797264                           ASSAULT
# 6797265                             THEFT
# 6797266                           BATTERY
# 6797267                           ROBBERY
# 6797268                   CRIMINAL DAMAGE
# 6797269                          BURGLARY
# 6797270                          BURGLARY
# 6797271                           ASSAULT
# 6797272                             THEFT
# 6797273               MOTOR VEHICLE THEFT
# 6797274                             THEFT
# 6797275                     OTHER OFFENSE
# 6797276                           ASSAULT
# 6797277                 CRIMINAL TRESPASS
# 6797278                           ASSAULT
# 6797279                           BATTERY
# 6797280                           BATTERY
# 6797281                           BATTERY
# 6797282                           ASSAULT
# 6797283                         NARCOTICS
# 6797284                           ASSAULT
# 6797285                             THEFT
# 6797286                             THEFT
# 6797287                             THEFT
# 6797288                             THEFT
# 6797290                             THEFT
# 6797291                           BATTERY
# 6797292                           BATTERY
# 6797293                     OTHER OFFENSE
# 6797294                   CRIMINAL DAMAGE
# 6797295                       SEX OFFENSE
# 6797296                         NARCOTICS
# 6797298                DECEPTIVE PRACTICE
# 6797299                   CRIMINAL DAMAGE
# 6797300                   CRIMINAL DAMAGE
# 6797301                   CRIMINAL DAMAGE
# 6797302                             THEFT
# 6797303                          BURGLARY
# 6797304               MOTOR VEHICLE THEFT
# 6797305                      INTIMIDATION
# 6797306                           ASSAULT
# 6797307                             THEFT
# 6797308                         NARCOTICS
# 6797309                             THEFT
# 6797310                         NARCOTICS
# 6797311                           ASSAULT
# 6797312                           ASSAULT
# 6797313                 CRIMINAL TRESPASS
# 6797314                 CRIMINAL TRESPASS
# 6797315                DECEPTIVE PRACTICE
# 6797316                           BATTERY
# 6797317                             THEFT
# 6797318                         NARCOTICS
# 6797319                           ROBBERY
# 6797320                DECEPTIVE PRACTICE
# 6797321                DECEPTIVE PRACTICE
# 6797322                         NARCOTICS
# 6797323                             THEFT
# 6797324                             THEFT
# 6797325                   CRIMINAL DAMAGE
# 6797326                             THEFT
# 6797328        OFFENSE INVOLVING CHILDREN
# 6797329                             THEFT
# 6797330                         NARCOTICS
# 6797331                     OTHER OFFENSE
# 6797332                             THEFT
# 6797333                             THEFT
# 6797334                             THEFT
# 6797335                             THEFT
# 6797336                          STALKING
# 6797337                             THEFT
# 6797338        OFFENSE INVOLVING CHILDREN
# 6797339                             THEFT
# 6797340                   CRIMINAL DAMAGE
# 6797341                   CRIMINAL DAMAGE
# 6797342                             THEFT
# 6797343               MOTOR VEHICLE THEFT
# 6797344                DECEPTIVE PRACTICE
# 6797345                   CRIMINAL DAMAGE
# 6797346                           BATTERY
# 6797347                           ASSAULT
# 6797348                             THEFT
# 6797349                             THEFT
# 6797350                             THEFT
# 6797351                           BATTERY
# 6797352                     OTHER OFFENSE
# 6797353                   CRIMINAL DAMAGE
# 6797354                             THEFT
# 6797355                             THEFT
# 6797356                           BATTERY
# 6797357                     OTHER OFFENSE
# 6797358                           ASSAULT
# 6797359                             THEFT
# 6797360                   CRIMINAL DAMAGE
# 6797361               MOTOR VEHICLE THEFT
# 6797362                             THEFT
# 6797363                             THEFT
# 6797364                   CRIMINAL DAMAGE
# 6797365                             THEFT
# 6797366                             THEFT
# 6797367                 WEAPONS VIOLATION
# 6797368                             THEFT
# 6797369                   CRIMINAL DAMAGE
# 6797370                             THEFT
# 6797371                             THEFT
# 6797372                             THEFT
# 6797373                   CRIMINAL DAMAGE
# 6797374                         NARCOTICS
# 6797375                DECEPTIVE PRACTICE
# 6797376                         NARCOTICS
# 6797377                             THEFT
# 6797378                DECEPTIVE PRACTICE
# 6797379                           ASSAULT
# 6797380                          BURGLARY
# 6797381                             THEFT
# 6797382                             THEFT
# 6797383                             THEFT
# 6797384                           ROBBERY
# 6797385                             THEFT
# 6797386                         NARCOTICS
# 6797387                             THEFT
# 6797388                         NARCOTICS
# 6797389                   CRIMINAL DAMAGE
# 6797390                             THEFT
# 6797391                 CRIMINAL TRESPASS
# 6797392                             THEFT
# 6797393                           BATTERY
# 6797394                             THEFT
# 6797395                DECEPTIVE PRACTICE
# 6797396                         NARCOTICS
# 6797397                   CRIMINAL DAMAGE
# 6797398                 WEAPONS VIOLATION
# 6797399                         NARCOTICS
# 6797400                           ROBBERY
# 6797401                             THEFT
# 6797402                   CRIMINAL DAMAGE
# 6797403                             THEFT
# 6797404                           BATTERY
# 6797405                             THEFT
# 6797406                             THEFT
# 6797407                          BURGLARY
# 6797408                           BATTERY
# 6797409                   CRIMINAL DAMAGE
# 6797410                         NARCOTICS
# 6797411                             THEFT
# 6797412                             THEFT
# 6797413                           BATTERY
# 6797414               MOTOR VEHICLE THEFT
# 6797415                             THEFT
# 6797416                 CRIMINAL TRESPASS
# 6797417                           BATTERY
# 6797418                             THEFT
# 6797419                         NARCOTICS
# 6797420                         NARCOTICS
# 6797421                           BATTERY
# 6797422                     OTHER OFFENSE
# 6797423                DECEPTIVE PRACTICE
# 6797424                 CRIMINAL TRESPASS
# 6797425                     OTHER OFFENSE
# 6797426                           ASSAULT
# 6797427                             THEFT
# 6797428                     OTHER OFFENSE
# 6797429                   CRIMINAL DAMAGE
# 6797430                             THEFT
# 6797431               MOTOR VEHICLE THEFT
# 6797432                   CRIMINAL DAMAGE
# 6797433                           BATTERY
# 6797435                           BATTERY
# 6797436                           ASSAULT
# 6797437                             THEFT
# 6797438  INTERFERENCE WITH PUBLIC OFFICER
# 6797439                           ROBBERY
# 6797440                           BATTERY
# 6797441                             THEFT
# 6797442                         NARCOTICS
# 6797443                           ROBBERY
# 6797444  INTERFERENCE WITH PUBLIC OFFICER
# 6797445                             THEFT
# 6797446               MOTOR VEHICLE THEFT
# 6797447                           BATTERY
# 6797448                             THEFT
# 6797449  INTERFERENCE WITH PUBLIC OFFICER
# 6797450                           ROBBERY
# 6797451                         NARCOTICS
# 6797452                     OTHER OFFENSE
# 6797453                           BATTERY
# 6797454                           ROBBERY
# 6797455                             THEFT
# 6797456                     OTHER OFFENSE
# 6797457                             THEFT
# 6797458                 CRIMINAL TRESPASS
# 6797459                 WEAPONS VIOLATION
# 6797460                           BATTERY
# 6797461                             THEFT
# 6797462                          BURGLARY
# 6797463                   CRIMINAL DAMAGE
# 6797464                             THEFT
# 6797465                             THEFT
# 6797466                   CRIMINAL DAMAGE
# 6797467                           BATTERY
# 6797468                 WEAPONS VIOLATION
# 6797469                           BATTERY
# 6797470                         NARCOTICS
# 6797471                           BATTERY
# 6797472                             THEFT
# 6797473               MOTOR VEHICLE THEFT
# 6797474                             THEFT
# 6797475                             THEFT
# 6797476                           BATTERY
# 6797477                             THEFT
# 6797478                     OTHER OFFENSE
# 6797479                           BATTERY
# 6797480                         NARCOTICS
# 6797481                             THEFT
# 6797482                     OTHER OFFENSE
# 6797483                   CRIMINAL DAMAGE
# 6797484                           BATTERY
# 6797485                           BATTERY
# 6797486                           ROBBERY
# 6797487               MOTOR VEHICLE THEFT
# 6797488               MOTOR VEHICLE THEFT
# 6797489                   CRIMINAL DAMAGE
# 6797490               MOTOR VEHICLE THEFT
# 6797491               MOTOR VEHICLE THEFT
# 6797492                   CRIMINAL DAMAGE
# 6797493                             THEFT
# 6797494                           BATTERY
# 6797495                           ROBBERY
# 6797496                           BATTERY
# 6797497                DECEPTIVE PRACTICE
# 6797498                   CRIMINAL DAMAGE
# 6797499                           BATTERY
# 6797500                 CRIMINAL TRESPASS
# 6797501                         NARCOTICS
# 6797503                           ASSAULT
# 6797504                           ASSAULT
# 6797505               MOTOR VEHICLE THEFT
# 6797506                           BATTERY
# 6797507                           BATTERY
# 6797508                           ROBBERY
# 6797509                          BURGLARY
# 6797510                             THEFT
# 6797511                 WEAPONS VIOLATION
# 6797512                             THEFT
# 6797513                 WEAPONS VIOLATION
# 6797514                           ROBBERY
# 6797515                           BATTERY
# 6797516                             THEFT
# 6797517                           ASSAULT
# 6797518                           BATTERY
# 6797519                   CRIMINAL DAMAGE
# 6797520                 WEAPONS VIOLATION
# 6797521                           BATTERY
# 6797522                           BATTERY
#
#                                                description  \
# 1                           AGG SEX ASSLT OF CHILD FAM MBR
# 2                           AGG SEX ASSLT OF CHILD FAM MBR
# 3                                         TELEPHONE THREAT
# 4                            SEX ASSLT OF CHILD BY FAM MBR
# 5                           FINANCIAL ID THEFT:$300 &UNDER
# 6                                                  FORGERY
# 7                                                OVER $500
# 8                                                   SIMPLE
# 9                            FINANCIAL ID THEFT: OVER $300
# 10                            CRIM SEX ABUSE BY FAM MEMBER
# 11                           FINANCIAL ID THEFT: OVER $300
# 12                           FINANCIAL ID THEFT: OVER $300
# 13                                FRAUD OR CONFIDENCE GAME
# 14                           AGG CRIM SEX ABUSE FAM MEMBER
# 15                                              TO VEHICLE
# 16                                             TO PROPERTY
# 17                                          NON-AGGRAVATED
# 19                           FINANCIAL ID THEFT: OVER $300
# 21                           FINANCIAL ID THEFT: OVER $300
# 22                                 AGG: FINANCIAL ID THEFT
# 30                                       AGGRAVATED: OTHER
# 32                           FINANCIAL ID THEFT: OVER $300
# 33                           FINANCIAL ID THEFT: OVER $300
# 34                                          $500 AND UNDER
# 35                           FINANCIAL ID THEFT: OVER $300
# 37                           FINANCIAL ID THEFT: OVER $300
# 38                                              TO VEHICLE
# 39                          AGG SEX ASSLT OF CHILD FAM MBR
# 40                                             TO PROPERTY
# 41                               AGG CRIMINAL SEXUAL ABUSE
# 42                                 AGG: FINANCIAL ID THEFT
# 43                          FINANCIAL ID THEFT:$300 &UNDER
# 44                                               PREDATORY
# 45                                              TO VEHICLE
# 46                           FINANCIAL ID THEFT: OVER $300
# 47                           FINANCIAL ID THEFT: OVER $300
# 48                           FINANCIAL ID THEFT: OVER $300
# 49                            CRIM SEX ABUSE BY FAM MEMBER
# 50                          FINANCIAL ID THEFT:$300 &UNDER
# 51                                 HARASSMENT BY TELEPHONE
# 52                           FINANCIAL ID THEFT: OVER $300
# 54                           FINANCIAL ID THEFT: OVER $300
# 55                                            EMBEZZLEMENT
# 56                          FINANCIAL ID THEFT:$300 &UNDER
# 57                           FINANCIAL ID THEFT: OVER $300
# ...
# 332        24     5
# 333        24     5
# 334        24     5
# 335        24     5
# 336        24     5
# 337        24     5
# 338        24     5
# 339        24     5
# 340        24     5
# 341        24     5
# 342        24     5
# 343        24     5
# 344        24     5
# 345        24     5
# 346        24     5
# 347        24     5
# 348        24     5
# 349        24     5
# 350        24     5
# 351        24     5
# 352        24     5
# 353        24     5
# 354        24     5
# 355        24     5
# 356        24     5
# 357        24     5
# 358        24     5
# 359        24     5
# 360        24     5
# 361        24     5
# 362        24     5
# 363        24     5
# 364        24     5
# 365        24     5
# 366        24     5
# 367        24     5
# 368        24     5
# 369        24     5
# 370        24     5
# 371        24     5
# 372        24     5
# 373        24     5
# 374        24     5
# 375        24     5
# 376        24     5
# 377        24     5
# 378        24     5
# 379        24     5
# 380        24     5
# 381        24     5
# 382        24     5
# 383        24     5
# 384        24     5
# 385        24     5
# 386        24     5
# 387        24     5
# 388        24     5
# 389        24     5
# 390        24     5
# 391        24     5
# 392        24     5
# 393        24     5
# 394        24     5
# 395        24     5
# 396        24     5
# 397        24     5
# 398        24     5
# 399        24     5
# 400        24     5
# 401        24     5
# 402        24     5
# 403        24     5
# 404        24     5
# 405        24     5
# 406        24     5
# 407        24     5
# 408        24     5
# 409        24     5
# 410        24     5
# 411        24     5
# 412        24     5
# 413        24     5
# 414        24     5
# 415        24     5
# 416        24     5
# 417        24     5
# 418        24     5
# 419        24     5
# 420        24     5
# 421        24     5
# 422        24     5
# 423        24     5
# 424        24     5
# 425        24     5
# 426        24     5
# 427        24     5
# 428        24     5
# 429        24     5
# 430        24     5
# 431        24     5
# 432        24     5
# 433        24     5
# 434        24     5
# 435        24     5
# 436        24     5
# 437        24     5
# 438        24     5
# 439        24     5
# 440        24     5
# 441        24     5
# 442        24     5
# 443        24     5
# 444        24     5
# 445        24     5
# 446        24     5
# 447        24     5
# 448        24     5
# 449        24     5
# 450        24     5
# 451        24     5
# 452        24     5
# 453        24     5
# 454        24     5
# 455        24     5
# 456        24     5
# 457        24     5
# 458        24     5
# 459        24     5
# 460        24     5
# 461        24     5
# 462        24     5
# 463        24     5
# 464        24     5
# 465        24     5
# 466        24     5
# 467        24     5
# 468        24     5
# 469        24     5
# 470        24     5
# 471        24     5
# 472        24     5
# 473        24     5
# 474        24     5
# 475        24     5
# 476        24     5
# 477        24     5
# 478        24     5
# 479        24     5
# 480        24     5
# 481        24     5
# 482        24     5
# 483        24     5
# 484        24     5
# 485        24     5
# 486        24     5
# 487        24     5
# 488        24     5
# 489        24     5
# 490        24     5
# 491        24     5
# 492        24     5
# 493        24     5
# 494        24     5
# 495        24     5
# 496        24     5
# 497        24     5
# 498        24     5
# 500        24     5
# 501        24     5
# 502        24     5
# 503        24     5
# 504        24     5
# 505        24     5
# 506        24     5
# 507        24     5
# 508        24     5
# 509        24     5
# 510        24     5
# 511        24     5
# 512        24     5
# 513        24     5
# 514        24     5
# 515        24     5
# 516        24     5
# 517        24     5
# 518        24     5
# 519        24     5
# 520        24     5
# 521        24     5
# 522        24     5
# 523        24     5
# 524        24     5
# 525        24     5
# 526        24     5
# 527        24     5
# 528        24     5
# 529        24     5
# 530        24     5
# 531        24     5
# 532        24     5
# 533        24     5
# 534        24     5
# 535        24     5
# 536        24     5
# 537        24     5
# 538        24     5
# 539        24     5
# 540        24     5
# 541        24     5
# 542        24     5
# 543        24     5
# 544        24     5
# 545        24     5
# 546        24     5
# 547        24     5
# 548        24     5
# 549        24     5
# 550        24     5
# 551        24     5
# 552        24     5
# 553        24     5
# 554        24     5
# 555        24     5
# 556        24     5
# ...       ...   ...
# 6797007    34    19
# 6797008    34    19
# 6797009    34    19
# 6797010    34    19
# 6797011    34    19
# 6797012    34    19
# 6797013    34    19
# 6797014    34    19
# 6797015    34    19
# 6797016    34    19
# 6797017    34    19
# 6797018    34    19
# 6797019    34    19
# 6797020    34    19
# 6797021    34    19
# 6797022    34    19
# 6797023    34    19
# 6797024    34    19
# 6797025    34    19
# 6797026    34    19
# 6797027    34    19
# 6797028    34    19
# 6797029    34    19
# 6797030    34    19
# 6797031    34    19
# 6797032    34    19
# 6797033    34    19
# 6797034    34    19
# 6797035    34    19
# 6797036    34    19
# 6797037    34    19
# 6797038    34    19
# 6797039    34    19
# 6797040    34    19
# 6797041    34    19
# 6797042    34    19
# 6797043    34    19
# 6797044    34    19
# 6797045    34    19
# 6797046    34    19
# 6797047    34    19
# 6797048    34    19
# 6797049    34    19
# 6797050    34    19
# 6797051    34    19
# 6797052    34    19
# 6797053    34    19
# 6797054    34    19
# 6797055    34    19
# 6797056    34    19
# 6797057    34    19
# 6797058    34    19
# 6797059    34    19
# 6797060    34    19
# 6797061    34    19
# 6797062    34    19
# 6797063    34    19
# 6797064    34    19
# 6797065    34    19
# 6797066    34    19
# 6797067    34    19
# 6797068    34    19
# 6797069    34    19
# 6797070    34    19
# 6797071    34    19
# 6797072    34    19
# 6797073    34    19
# 6797074    34    19
# 6797077    34    19
# 6797078    34    19
# 6797079    34    19
# 6797080    34    19
# 6797081    34    19
# 6797082    34    19
# 6797083    34    19
# 6797084    34    19
# 6797085    34    19
# 6797086    34    19
# 6797087    34    19
# 6797088    34    19
# 6797089    34    19
# 6797090    34    19
# 6797091    34    19
# 6797092    34    19
# 6797093    34    19
# 6797094    34    19
# 6797095    34    19
# 6797096    34    19
# 6797097    34    19
# 6797098    34    19
# 6797099    34    19
# 6797100    34    19
# 6797101    34    19
# 6797102    34    19
# 6797103    34    19
# 6797104    34    19
# 6797105    34    19
# 6797107    34    19
# 6797108    34    19
# 6797109    34    19
# 6797110    34    19
# 6797111    34    19
# 6797112    34    19
# 6797113    34    19
# 6797114    34    19
# 6797115    34    19
# 6797116    34    19
# 6797117    34    19
# 6797118    34    19
# 6797119    34    19
# 6797120    34    19
# 6797121    34    19
# 6797122    34    19
# 6797123    34    19
# 6797124    34    19
# 6797126    34    19
# 6797127    34    19
# 6797128    34    19
# 6797129    34    19
# 6797130    34    19
# 6797131    34    19
# 6797132    34    19
# 6797133    34    19
# 6797134    34    19
# 6797137    34    19
# 6797138    34    19
# 6797139    34    19
# 6797140    34    19
# 6797141    34    19
# 6797142    34    19
# 6797143    34    19
# 6797144    34    19
# 6797145    34    19
# 6797146    34    19
# 6797147    34    19
# 6797148    34    19
# 6797149    34    19
# 6797150    34    19
# 6797151    34    19
# 6797152    34    19
# 6797153    34    19
# 6797154    34    19
# 6797155    34    19
# 6797156    34    19
# 6797157    34    19
# 6797158    34    19
# 6797159    34    19
# 6797160    34    19
# 6797161    34    19
# 6797162    34    19
# 6797163    34    19
# 6797164    34    19
# 6797165    34    19
# 6797166    34    19
# 6797167    34    19
# 6797168    34    19
# 6797169    34    19
# 6797170    34    19
# 6797171    34    19
# 6797172    34    19
# 6797173    34    19
# 6797174    34    19
# 6797175    34    19
# 6797176    34    19
# 6797177    34    19
# 6797178    34    19
# 6797179    34    19
# 6797180    34    19
# 6797182    34    19
# 6797183    34    19
# 6797184    34    19
# 6797185    34    19
# 6797186    34    19
# 6797187    34    19
# 6797188    34    19
# 6797189    34    19
# 6797190    34    19
# 6797191    34    19
# 6797192    34    19
# 6797193    34    19
# 6797194    34    19
# 6797195    34    19
# 6797196    34    19
# 6797198    34    19
# 6797199    34    19
# 6797200    34    19
# 6797201    34    19
# 6797202    34    19
# 6797203    34    19
# 6797205    34    19
# 6797206    34    19
# 6797208    34    19
# 6797209    34    19
# 6797210    34    19
# 6797211    34    19
# 6797212    34    19
# 6797213    34    19
# 6797214    34    19
# 6797215    34    19
# 6797216    34    19
# 6797217    34    19
# 6797218    34    19
# 6797219    34    19
# 6797220    34    19
# 6797221    34    19
# 6797222    34    19
# 6797223    34    19
# 6797224    34    19
# 6797225    34    19
# 6797226    34    19
# 6797227    34    19
# 6797228    34    19
# 6797229    34    19
# 6797230    34    19
# 6797231    34    19
# 6797232    34    19
# 6797233    34    19
# 6797234    34    19
# 6797235    34    19
# 6797236    34    19
# 6797237    34    19
# 6797238    34    19
# 6797239    34    19
# 6797240    34    19
# 6797241    34    19
# 6797242    34    19
# 6797243    34    19
# 6797244    34    19
# 6797245    34    19
# 6797246    34    19
# 6797247    34    19
# 6797248    34    19
# 6797249    34    19
# 6797250    34    19
# 6797251    34    19
# 6797252    34    19
# 6797253    34    19
# 6797254    34    19
# 6797255    34    19
# 6797256    34    19
# 6797258    34    19
# 6797259    34    19
# 6797260    34    19
# 6797261    34    19
# 6797262    34    19
# 6797263    34    19
# 6797264    34    19
# 6797265    34    19
# 6797266    34    19
# 6797267    34    19
# 6797268    34    19
# 6797269    34    19
# 6797270    34    19
# 6797271    34    19
# 6797272    34    19
# 6797273    34    19
# 6797274    34    19
# 6797275    34    19
# 6797276    34    19
# 6797277    34    19
# 6797278    34    19
# 6797279    34    19
# 6797280    34    19
# 6797281    34    19
# 6797282    34    19
# 6797283    34    19
# 6797284    34    19
# 6797285    34    19
# 6797286    34    19
# 6797287    34    19
# 6797288    34    19
# 6797290    34    19
# 6797291    34    19
# 6797292    34    19
# 6797293    34    19
# 6797294    34    19
# 6797295    34    19
# 6797296    34    19
# 6797298    34    19
# 6797299    34    19
# 6797300    34    19
# 6797301    34    19
# 6797302    34    19
# 6797303    34    19
# 6797304    34    19
# 6797305    34    19
# 6797306    34    19
# 6797307    34    19
# 6797308    34    19
# 6797309    34    19
# 6797310    34    19
# 6797311    34    19
# 6797312    34    19
# 6797313    34    19
# 6797314    34    19
# 6797315    34    19
# 6797316    34    19
# 6797317    34    19
# 6797318    34    19
# 6797319    34    19
# 6797320    34    19
# 6797321    34    19
# 6797322    34    19
# 6797323    34    19
# 6797324    34    19
# 6797325    34    19
# 6797326    34    19
# 6797328    34    19
# 6797329    34    19
# 6797330    34    19
# 6797331    34    19
# 6797332    34    19
# 6797333    34    19
# 6797334    34    19
# 6797335    34    19
# 6797336    34    19
# 6797337    34    19
# 6797338    34    19
# 6797339    34    19
# 6797340    34    19
# 6797341    34    19
# 6797342    34    19
# 6797343    34    19
# 6797344    34    19
# 6797345    34    19
# 6797346    34    19
# 6797347    34    19
# 6797348    34    19
# 6797349    34    19
# 6797350    34    19
# 6797351    34    19
# 6797352    34    19
# 6797353    34    19
# 6797354    34    19
# 6797355    34    19
# 6797356    34    19
# 6797357    34    19
# 6797358    34    19
# 6797359    34    19
# 6797360    34    19
# 6797361    34    19
# 6797362    34    19
# 6797363    34    19
# 6797364    34    19
# 6797365    34    19
# 6797366    34    19
# 6797367    34    19
# 6797368    34    19
# 6797369    34    19
# 6797370    34    19
# 6797371    34    19
# 6797372    34    19
# 6797373    34    19
# 6797374    34    19
# 6797375    34    19
# 6797376    34    19
# 6797377    34    19
# 6797378    34    19
# 6797379    34    19
# 6797380    34    19
# 6797381    34    19
# 6797382    34    19
# 6797383    34    19
# 6797384    34    19
# 6797385    34    19
# 6797386    34    19
# 6797387    34    19
# 6797388    34    19
# 6797389    34    19
# 6797390    34    19
# 6797391    34    19
# 6797392    34    19
# 6797393    34    19
# 6797394    34    19
# 6797395    34    19
# 6797396    34    19
# 6797397    34    19
# 6797398    34    19
# 6797399    34    19
# 6797400    34    19
# 6797401    34    19
# 6797402    34    19
# 6797403    34    19
# 6797404    34    19
# 6797405    34    19
# 6797406    34    19
# 6797407    34    19
# 6797408    34    19
# 6797409    34    19
# 6797410    34    19
# 6797411    34    19
# 6797412    34    19
# 6797413    34    19
# 6797414    34    19
# 6797415    34    19
# 6797416    34    19
# 6797417    34    19
# 6797418    34    19
# 6797419    34    19
# 6797420    34    19
# 6797421    34    19
# 6797422    34    19
# 6797423    34    19
# 6797424    34    19
# 6797425    34    19
# 6797426    34    19
# 6797427    34    19
# 6797428    34    19
# 6797429    34    19
# 6797430    34    19
# 6797431    34    19
# 6797432    34    19
# 6797433    34    19
# 6797435    34    19
# 6797436    34    19
# 6797437    34    19
# 6797438    34    19
# 6797439    34    19
# 6797440    34    19
# 6797441    34    19
# 6797442    34    19
# 6797443    34    19
# 6797444    34    19
# 6797445    34    19
# 6797446    34    19
# 6797447    34    19
# 6797448    34    19
# 6797449    34    19
# 6797450    34    19
# 6797451    34    19
# 6797452    34    19
# 6797453    34    19
# 6797454    34    19
# 6797455    34    19
# 6797456    34    19
# 6797457    34    19
# 6797458    34    19
# 6797459    34    19
# 6797460    34    19
# 6797461    34    19
# 6797462    34    19
# 6797463    34    19
# 6797464    34    19
# 6797465    34    19
# 6797466    34    19
# 6797467    34    19
# 6797468    34    19
# 6797469    34    19
# 6797470    34    19
# 6797471    34    19
# 6797472    34    19
# 6797473    34    19
# 6797474    34    19
# 6797475    34    19
# 6797476    34    19
# 6797477    34    19
# 6797478    34    19
# 6797479    34    19
# 6797480    34    19
# 6797481    34    19
# 6797482    34    19
# 6797483    34    19
# 6797484    34    19
# 6797485    34    19
# 6797486    34    19
# 6797487    34    19
# 6797488    34    19
# 6797489    34    19
# 6797490    34    19
# 6797491    34    19
# 6797492    34    19
# 6797493    34    19
# 6797494    34    19
# 6797495    34    19
# 6797496    34    19
# 6797497    34    19
# 6797498    34    19
# 6797499    34    19
# 6797500    34    19
# 6797501    34    19
# 6797503    34    19
# 6797504    34    19
# 6797505    34    19
# 6797506    34    19
# 6797507    34    19
# 6797508    34    19
# 6797509    34    19
# 6797510    34    19
# 6797511    34    19
# 6797512    34    19
# 6797513    34    19
# 6797514    34    19
# 6797515    34    19
# 6797516    34    19
# 6797517    34    19
# 6797518    34    19
# 6797519    34    19
# 6797520    34    19
# 6797521    34    19
# 6797522    34    19
#
# [6735796 rows x 17 columns]

# %%
df = df.drop('index', axis = 1)

# %%
df = df.drop('casenumber', axis = 1)

# %%
df = df.drop('id', axis = 1)

# %%
df = df.drop('block', axis = 1)

# %%
df['primarytype'] = df['primarytype'].astype('category')

# %%
df['description'] = df['description'].astype('category')

# %%
df['locationdescription'] = df['locationdescription'].astype('category')

# %%
#df['arrest'] = df['arrest'].astype('int')
df['arrest'].replace('true', 1, inplace = True)
df['arrest'].replace('false', 0, inplace = True)

# %%
#df['domestic'] = df['domestic'].astype('bool')
df['domestic'].replace('true', 1, inplace = True)
df['domestic'].replace('false', 0, inplace = True)

# %%
df['fbicode'] = df['fbicode'].astype('category')

# %%
df = df.drop('date_x', axis = 1)

# %%
df['xcoordinate'] = df['xcoordinate'].fillna(value=np.nan)

# %%
df['xcoordinate'] = df['xcoordinate'].astype('int64', errors = 'ignore')

# %%
df['ycoordinate'] = df['ycoordinate'].fillna(value=np.nan)

# %%
df['ycoordinate'] = df['ycoordinate'].astype('int64', errors = 'ignore')

# %%
df = df.drop('year', axis = 1)

# %%
df = df.drop('updatedon', axis = 1)

# %%
df['latitude'] = df['latitude'].astype('float64', errors = 'ignore')

# %%
df['longitude'] = df['longitude'].astype('float64', errors = 'ignore')

# %%
df = df.drop('location', axis = 1)

# %%
df['station'] = df['station'].astype('category')

# %%
df = df.drop('name', axis = 1)

# %%
df = df.drop('date_y', axis = 1)

# %%
df = df.drop('iucr', axis = 1)

# %%
df.to_feather('chicago_crime_cleaned.feather')

# %%
df = feather.read_dataframe('chicago_crime_cleaned.feather')

# %%
df = df.drop(['wdf2', 'wdf5', 'wesd', 'wsf2', 'wsf5', 'wt01',
       'wt02', 'wt03', 'wt04', 'wt05', 'wt06', 'wt07', 'wt08', 'wt09', 'wt11',
       'wt13', 'wt14', 'wt15', 'wt16', 'wt17', 'wt18', 'wt19', 'wt21', 'wt22',
       'wv03', 'wv20', 'tsun'], axis = 1)

# %%
df = df.drop('station', axis = 1)

# %%
df = df.drop('fmtm', axis = 1)

# %%
df = df.drop('pgtm', axis = 1)

# %%
df = df.drop('snwd', axis = 1)

# %%
df = df.drop('xcoordinate', axis = 1)
df = df.drop('ycoordinate', axis = 1)

# %%
df = df.drop('datetime', axis = 1)

# %%
df = df.dropna(subset=['district'])

# %%
df = df.drop('tavg', axis = 1)

# %%
df = df.dropna(subset=['latitude'])

# %%
df['locationdescription'] = df.locationdescription.fillna(value='OTHER')

# %%
df['communityarea'] = df.sort_values(by=['beat', 'district', 'ward'])['communityarea'].fillna(method='ffill')

# %%
df['ward'] = df.sort_values(by=['beat', 'district', 'communityarea'])['ward'].fillna(method='ffill')

# %%
for header in df.columns:
    
    nulls_count = df[f'{header}'].isnull().sum()
    
    print(f'There are {nulls_count} in {header}')

# %% [markdown]
# ## EDA

# %%
df = df.reset_index()

# %%
df.to_feather('chicago_crime_final.feather')

# %%
df = feather.read_dataframe('chicago_crime_final.feather')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6735796 entries, 0 to 6735795
# Data columns (total 18 columns):
# index                  int64
# primarytype            category
# description            category
# locationdescription    category
# arrest                 int64
# domestic               int64
# beat                   int64
# district               float64
# ward                   float64
# communityarea          float64
# fbicode                category
# latitude               float64
# longitude              float64
# awnd                   float64
# prcp                   float64
# snow                   float64
# tmax                   int64
# tmin                   int64
# dtypes: category(4), float64(8), int64(6)
# memory usage: 758.0 MB

# %%
df.corr()
# Out:
#                   index    arrest  domestic      beat  district      ward  \
# index          1.000000 -0.055044  0.043370 -0.035996 -0.004956  0.013127
# arrest        -0.055044  1.000000 -0.069274 -0.015993 -0.016780 -0.015836
# domestic       0.043370 -0.069274  1.000000 -0.041821 -0.038657 -0.050101
# beat          -0.035996 -0.015993 -0.041821  1.000000  0.939092  0.635785
# district      -0.004956 -0.016780 -0.038657  0.939092  1.000000  0.688740
# ward           0.013127 -0.015836 -0.050101  0.635785  0.688740  1.000000
# communityarea  0.004968 -0.008292  0.072056 -0.506381 -0.499337 -0.532559
# latitude      -0.005265  0.002096 -0.075669  0.612650  0.620597  0.626385
# longitude      0.001056 -0.031477  0.004518 -0.473687 -0.528367 -0.432463
# awnd           0.036246  0.001616  0.002332 -0.003126 -0.001122  0.000059
# prcp           0.016684 -0.009167  0.002825 -0.000468 -0.000027 -0.000011
# snow           0.020514  0.002330  0.002082  0.000737  0.000919  0.001221
# tmax           0.017340 -0.023662  0.004467 -0.002075 -0.001339 -0.000049
# tmin           0.038502 -0.025416  0.003772 -0.002319 -0.001220  0.000588
#
#                communityarea  latitude  longitude      awnd      prcp  \
# index               0.004968 -0.005265   0.001056  0.036246  0.016684
# arrest             -0.008292  0.002096  -0.031477  0.001616 -0.009167
# domestic            0.072056 -0.075669   0.004518  0.002332  0.002825
# beat               -0.506381  0.612650  -0.473687 -0.003126 -0.000468
# district           -0.499337  0.620597  -0.528367 -0.001122 -0.000027
# ward               -0.532559  0.626385  -0.432463  0.000059 -0.000011
# communityarea       1.000000 -0.747118   0.240317  0.000821  0.001185
# latitude           -0.747118  1.000000  -0.410834 -0.000028 -0.000483
# longitude           0.240317 -0.410834   1.000000 -0.002323  0.000345
# awnd                0.000821 -0.000028  -0.002323  1.000000  0.080271
# prcp                0.001185 -0.000483   0.000345  0.080271  1.000000
# snow               -0.000435  0.001649  -0.002221  0.099045  0.104215
# tmax                0.001802 -0.003313   0.007822 -0.250733  0.092846
# tmin                0.001377 -0.002630   0.007829 -0.215913  0.142637
#
#                    snow      tmax      tmin
# index          0.020514  0.017340  0.038502
# arrest         0.002330 -0.023662 -0.025416
# domestic       0.002082  0.004467  0.003772
# beat           0.000737 -0.002075 -0.002319
# district       0.000919 -0.001339 -0.001220
# ward           0.001221 -0.000049  0.000588
# communityarea -0.000435  0.001802  0.001377
# latitude       0.001649 -0.003313 -0.002630
# longitude     -0.002221  0.007822  0.007829
# awnd           0.099045 -0.250733 -0.215913
# prcp           0.104215  0.092846  0.142637
# snow           1.000000 -0.227082 -0.203525
# tmax          -0.227082  1.000000  0.941816
# tmin          -0.203525  0.941816  1.000000

# %%
df = pd.concat([df, pd.get_dummies(df['primarytype'])], axis = 1)

# %%
df = df.drop('primarytype', axis = 1)

# %%
#df = pd.concat([df, pd.get_dummies(df['description'])], axis = 1)

# %%
df = df.drop('description', axis = 1)

# %%
df = pd.concat([df, pd.get_dummies(df['locationdescription'])], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3266                 else:
# -> 3267                     exec(code_obj, self.user_global_ns, self.user_ns)
#    3268             finally:
#
# <ipython-input-9-159e3334239b> in <module>
# ----> 1 df = pd.concat([df, pd.get_dummies(df['locationdescription'])], axis = 1)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     225                        copy=copy, sort=sort)
# --> 226     return op.get_result()
#     227
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     422                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 423                 copy=self.copy)
#     424             if not self.copy:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    5411             if copy:
# -> 5412                 values = values.copy()
#    5413             elif not copy:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
df = df.drop('fbicode', axis = 1)

# %%
df = df.drop('locationdescription', axis = 1)

# %% [markdown]
# ## Create a Model

# %%
#df.to_feather('chicago_crime_model_data.feather')

# %%
df = feather.read_dataframe('chicago_crime_model_data.feather')

# %%
df = df[0:1000000]

# %%
df.shape
# Out:
# (1000000, 228)

# %%
df.columns
# Out:
# Index(['index', 'arrest', 'domestic', 'beat', 'district', 'ward',
#        'communityarea', 'latitude', 'longitude', 'awnd',
#        ...
#        'VEHICLE - OTHER RIDE SHARE SERVICE (E.G., UBER, LYFT)',
#        'VEHICLE NON-COMMERCIAL', 'VEHICLE-COMMERCIAL',
#        'VEHICLE-COMMERCIAL - ENTERTAINMENT/PARTY BUS',
#        'VEHICLE-COMMERCIAL - TROLLEY BUS', 'VESTIBULE', 'WAREHOUSE',
#        'WOODED AREA', 'YARD', 'YMCA'],
#       dtype='object', length=228)

# %%
df = df[['index', 'arrest', 'domestic', 'beat']]

# %%
df.head()
# Out:
#    index  arrest  domestic  beat
# 0      1       0         0   511
# 1      2       0         0   512
# 2      3       0         0  1013
# 3      4       1         0   813
# 4      5       0         0  1033

# %%
y = df['arrest']
X = df.drop('arrest', axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# Need to standardize!!!!!

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
clf_log = LogisticRegression().fit(X_train_scaled, y_train)

# %%
clf_log.score(X_test_scaled, y_test)
# Out:
# 0.8599466666666666

# %%
preds_log = clf_log.predict(X_test)

# %%
roc_auc_score(y_test, preds_log)
# Out:
# 0.5002236680001253

# %% [markdown]
# ### Random Forest

# %%
len(df.columns)
# Out:
# 4

# %%
clf = RandomForestClassifier(oob_score=True, n_jobs=-1).fit(X_train, y_train)

# %%
X_train
# Out:
#           index  domestic  beat
# 506532   510683         0  1312
# 327991   329990         0  1022
# 715937   728120         0  2533
# 860726   876361         0  1532
# 78617     79071         0   813
# 394612   396994         0   314
# 609887   619573         0  1233
# 471099   473880         0  2432
# 80595     81058         1  1032
# 995080  1013970         0   912
# 222476   223751         0   511
# 557071   563891         0  1923
# 943609   961673         1  1533
# 955853   974158         0  2514
# 904469   921829         0  1431
# 607060   616562         0  2233
# 721613   733918         0  1422
# 141378   142175         0   213
# 253387   254896         0  2411
# 48330     48628         0   634
# 797282   811297         0  1422
# 644130   654735         0   413
# 557784   564640         0   833
# 748454   761379         0  1323
# 552784   559373         0   831
# 779959   793580         0   922
# 856655   872169         0   211
# 383480   385791         0   912
# 790297   804146         0   432
# 559078   566014         1   414
# ...         ...       ...   ...
# 103355   103937         0  2122
# 791743   805622         0  1532
# 199041   200183         0  2223
# 776997   790549         0  2431
# 327069   329061         0   713
# 718315   730548         0   411
# 321879   323828         0  2232
# 787201   800993         0  2124
# 64820     65205         0  1932
# 329365   331367         0   212
# 41090     41357         0  2532
# 278167   279837         0  2131
# 191335   192421         0  1813
# 175203   176198         0  2531
# 912756   930503         0   912
# 899159   916280         0  2331
# 87498     87996         0  1021
# 954698   972933         0   411
# 521430   526365         0  1231
# 999890  1018785         0  1621
# 137337   138104         1  1223
# 54886     55223         0   224
# 732180   744726         1  1533
# 110268   110882         0   925
# 644167   654773         0   634
# 259178   260723         0  1732
# 365838   368052         0  2323
# 131932   132675         0  1623
# 671155   682326         0  1134
# 121958   122650         0  1312
#
# [700000 rows x 3 columns]

# %%
train_preds = clf.predict(X_train)

# %%
pd.to_pickle(clf, "pkl_simple.p")

# %%
pickle.dump(clf, open("pkl_simple.p"), "wb")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-6fba7517c615> in <module>
# ----> 1 pickle.dump(clf, open("pkl_simple.p"), "wb")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pkl_simple.p'

# %%
clf.oob_score_
# Out:
# 0.8633946524930664

# %%
preds = clf.predict(X_test)

# %%
roc_auc_score(y_test, preds)
# Out:
# 0.8036966665451021

# %%
clf.score(X_test, y_test)
# Out:
# 0.8734265038681394

# %%
preds = clf.predict(X_test)

# %%
roc_auc_score(y_test, preds)
# Out:
# 0.7983847439909436

# %% [markdown]
# kernel SVM, KNN, Extra Trees
